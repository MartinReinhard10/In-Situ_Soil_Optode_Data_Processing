# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# Read image
image = cv2.imread('D:/raw_image.tiff', cv2.IMREAD_UNCHANGED)
print(np.shape(image))

# Remove padding in dataset 
image = image[:,:4056]
print(np.shape(image))
# Out:
# (3040, 4064)
# (3040, 4056)

# %%
center_row = 3040 // 2  
center_col = 4056 // 2  

center_pixel = (center_row, center_col)
print(center_pixel)

crop_x1 = center_col-1240
crop_x2 = center_col+1240
crop_y1 = center_row-930
crop_y2 = center_row+930
crop = image[crop_y1:crop_y2,crop_x1:crop_x2]


plt.imshow(crop, cmap="gray")
print(np.shape(crop))
# Out:
# (1520, 2028)
# (1860, 2480)
